# %% [markdown]
# <a href="https://colab.research.google.com/github/Marcosias0400/Optimizacion/blob/main/Ejercicio2Opti.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline

# %%
import numpy as np
import scipy.optimize as opt
import matplotlib.pyplot as plt

# %% [markdown]
# #Funcion a Optimizar
# f(x,y)=xy

# %%
def f(x):
    return x[0]*x[1]

# %%
x = np.linspace(-1.5, 1.5, 100)
y = np.linspace(-1.5, 1.5, 100)
X, Y = np.meshgrid(x, y)
Z = f(np.vstack([X.ravel(), Y.ravel()])).reshape((100,100))
plt.figure(figsize=(10,8))
plt.contour(X, Y, Z, np.arange(-10,10, 0.05), cmap='jet');
plt.plot(x, np.sqrt(1-x**2), 'k:', linewidth=1)
plt.plot(x, -np.sqrt(1-x**2), 'k:', linewidth=1)
plt.xlabel('$x$'); plt.ylabel('$y$');
plt.title("Proyección en el plano XY")
plt.axis([-1.5,1.5,-1.5,1.5])
# Out:
# <ipython-input-38-253a6540a03f>:7: RuntimeWarning: invalid value encountered in sqrt
#   plt.plot(x, np.sqrt(1-x**2), 'k:', linewidth=1)
# <ipython-input-38-253a6540a03f>:8: RuntimeWarning: invalid value encountered in sqrt
#   plt.plot(x, -np.sqrt(1-x**2), 'k:', linewidth=1)
# (-1.5, 1.5, -1.5, 1.5)

# %%
cons = ({'type': 'eq',
         'fun' : lambda x: np.array([x[0]**2+x[1]**2-1])})#,
         #'jac' : lambda x: np.array([1.0, 2.0*x[1]])})

bnds = ((-1.05, 1.05), (-1.05, 1.05))

# %%
x0 = [np.sqrt(2)/2, np.sqrt(2)/2]

# %%
ux = opt.minimize(f, x0, constraints=None)
ux
# Out:
#   message: Optimization terminated successfully.
#   success: True
#    status: 0
#       fun: 2.163214104424007e-17
#         x: [ 4.651e-09  4.651e-09]
#       nit: 1
#       jac: [ 4.651e-09  4.651e-09]
#  hess_inv: [[1 0]
#             [0 1]]
#      nfev: 6
#      njev: 2

# %%
cx = opt.minimize(f, x0, bounds=bnds, constraints=cons)
cx
# Out:
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5000000000000001
#        x: [ 7.071e-01  7.071e-01]
#      nit: 1
#      jac: [ 7.071e-01  7.071e-01]
#     nfev: 3
#     njev: 1
